# %%
import random
import itertools

results = {
    'heads': 0,
    'tails': 0,
}
sides = list(results.keys())
bet = input('What is your bet heads or tails : ')
tries = int(input('Enter number of tries :'))


import cv2
import numpy as np


window_name = "window"
interframe_wait_ms = 30

cap = cv2.VideoCapture('d74906d39a1964e7d07555e7601b06ad.gif')
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while (True):
    ret, frame = cap.read()
    if not ret:
        print()
        break

    cv2.imshow(window_name, frame)
    if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
        print("Exit requested.")
        break

cap.release()
cv2.destroyAllWindows()


for i in range(tries):
    results[random.choice(sides)] += 1
    


if bet == 'heads' and results['heads'] > results['tails']:
    import cv2
    import numpy as np


    window_name = "window"
    interframe_wait_ms = 50

    cap = cv2.VideoCapture('4A5.gif')
    if not cap.isOpened():
        print()
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print()
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()

    
    print('You won ')

elif bet == 'tails' and results['heads'] < results['tails']:
    import cv2
    import numpy as np


    window_name = "window"
    interframe_wait_ms = 70

    cap = cv2.VideoCapture('4A5.gif')
    if not cap.isOpened():
        print()
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print()
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()

    
    
    print('You won ')

else:
    if bet == 'heads' and results['heads'] < results['tails']:
        ans = results['tails'] - results['heads']
        
    elif bet == 'tails' and results['heads'] > results['tails']:
        ans = results['heads'] - results['tails']
        
        
    import cv2
    import numpy as np


    window_name = "window"
    interframe_wait_ms = 70

    cap = cv2.VideoCapture('motivation.gif')
    if not cap.isOpened():
        print()
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print()
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()


    
    print('Oops! this time you just lost by ',ans,' So do not loose hope you still have 50% chance to get your luck in the next try :')
# Out:
# What is your bet heads or tails : heads
# Enter number of tries :10
#
#
# You won
